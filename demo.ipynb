# %%
import os
import cv2
import time
import argparse
import numpy as np

from detector import build_detector
from utils.parser import get_config
import matplotlib.pyplot as plt

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--config_detection", type=str, default="./configs/yolov3.yaml")
parser.add_argument("--save_path", type=str, default="./output/")
parser.add_argument("--cpu", dest="use_cuda", action="store_false", default=True)
parser.add_argument("--camera", action="store", dest="cam", type=int, default="-1")
args =  parser.parse_known_args()[0]
cfg = get_config()
cfg.merge_from_file(args.config_detection)
# Out:
# /home/pubix/University/IoT/HumanDetection/utils/parser.py:23: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.update(yaml.load(fo.read()))

# %%
detector = build_detector(cfg, use_cuda=False)

# %%
class_names = detector.class_names

# %%
ori_im = cv2.imread('input/pic.jpg')
im = cv2.cvtColor(ori_im, cv2.COLOR_BGR2RGB)

# do detection
bbox_xywh, cls_conf, cls_ids = detector(im)

# %%
plt.imshow(im)

# %%
if (cls_ids==0).any():
    print('Found at least one human')
else:
    print('Found nothing')
# Out:
# Found at least one human

# %%
# select person class
mask = cls_ids == 0

bbox_xywh = bbox_xywh[mask]
# bbox dilation just in case bbox too small, delete this line if using a better pedestrian detector
bbox_xywh[:, 3:] *= 1.2
cls_conf = cls_conf[mask]

# %%
for i, c in enumerate(cls_ids):
    if c == 0:
        x1, y1,w,h = bbox_xywh[i]
        
        x2 = int(x1+(w/2))
        y2 = int(y1+(h/2))
        
        x1 = int(x1-(w/2))
        y1 = int(y1-(h/2))
        cv2.rectangle(im,(x1, y1),(x2,y2),(255,255,255),3)

# %%
plt.figure(figsize=[20,10])
plt.imshow(im)

# %% [markdown]
# ##
